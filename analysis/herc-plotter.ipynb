# %% [markdown]
# # Log data

# %% [markdown]
# ## load libraries

# %%
import os.path

# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
import time

import pandas as pd

import dateutil.parser

from io import StringIO

import requests
import ssl

import datetime

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:2000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:2000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %%
#base_url='http://nautilusdataviz.media.mit.edu:8888/files/'
#base_url='https://external.oet.org/science/monitor/'
#base_url='http://shiphouse.nautilus/science/monitor/'
filenames=['Herc-Depth.samples','Temperature.samples','Salinity.samples']

colnames=['date','salinity']


logfile='log_'+filenames[2]

filename=filenames[2]

# %%
def plotter(ax,dat,colname):
    #x=np.linspace(0,1,len(dat)) #replace this with dates
    x=dat['date'].tolist()
    y=dat[colname].tolist()
    #ax.plot(x, y, color)
    ax.plot(x, y,'-o')
    fig.canvas.draw()
    
def update(ax,dat,colname):
    #x=np.linspace(0,1,len(dat)) #replace this with dates
    x=dat['date'].tolist()
    y=dat[colname].tolist()
    if ax.lines:
        for line in ax.lines:
            line.set_xdata(x)
            y=dat[colname].tolist()
            line.set_ydata(y)
    ax.relim()
    ax.autoscale_view(True,True,True)

# %% [markdown]
# # Plotting

# %%
fig,ax = plt.subplots(2)
ax[0].set_ylabel('salinity')
ax[1].set_ylabel('temp')
# Out:
# <img src="data:image/png;base64,...">

# %%
# initial plot

colnames=['Salinity','Temperature']

index=0

for index in range(0,2):

    colname=colnames[index]   
    filename=colname+'.samples'
    logfile='log_'+filename

    log=pd.read_csv(logfile,delimiter=' ',names=['date',colname])

    plotter(ax[index],log,colname)

# %%
# update

def group_update(colnames):

    index = 0 

    for index in range(0,2):
        colname=colnames[index]
        filename=colname+'.samples'
        logfile='log_'+filename
        print(logfile)
        log=pd.read_csv(logfile,delimiter=' ',names=['date',colname])
        update(ax[index],log, colname)

# %%
group_update(colnames)
# Out:
# log_Salinity.samples
# log_Temperature.samples

# %%
while True:
    group_update()
    output='updated '
    ts = time.time()
    st = datetime.datetime.fromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')
    print(output+st)
    time.sleep(30)
# Out:
# updated 2016-07-24 22:13:07
# updated 2016-07-24 22:13:37
# updated 2016-07-24 22:14:07
# updated 2016-07-24 22:14:38
# updated 2016-07-24 22:15:08
# updated 2016-07-24 22:15:38
# updated 2016-07-24 22:16:08
# updated 2016-07-24 22:16:38
# updated 2016-07-24 22:17:08
# updated 2016-07-24 22:17:38
# updated 2016-07-24 22:18:08
# updated 2016-07-24 22:18:38
# updated 2016-07-24 22:19:08
# updated 2016-07-24 22:19:38
# updated 2016-07-24 22:20:08
# updated 2016-07-24 22:20:38
# updated 2016-07-24 22:21:08
# updated 2016-07-24 22:21:38
